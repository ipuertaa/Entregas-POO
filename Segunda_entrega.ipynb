# %% [markdown]
# Ejercicio 2.1 - Página 63

# %%
from enum import Enum

class gender(Enum):
  MASCULINE = "H"
  FEMININE = "M"

class Person:
  def __init__(self, name, lastname, ID, year_of_birth, country, gender):
    self.name = str(name)
    self.lastname = str(lastname)
    self.ID = ID
    self.year_of_birth = year_of_birth
    self.country = str(country)
    self.gender = gender

  def print_information(self):
    print(f"Nombres = {self.name}")
    print(f"Apellidos = {self.lastname}")
    print(f"Documento de identidad = {self.ID}")
    print(f"Año de nacimiento = {self.year_of_birth}")
    print(f"País de nacimiento = {self.country}")
    print(f"Género = {self.gender.value}")

if __name__ == "__main__":
  person_1 = Person("Isabel", "Puerta Álvarez", 123456789, 2001,"Colombia", gender.FEMININE)
  person_2 = Person(" María Camila", "Rojas Herrera", 987654321, 2004, "Colombia", gender.FEMININE)
  person_1.print_information()
  person_2.print_information()
# Out:
# Nombres = Isabel
# Apellidos = Puerta Álvarez
# Documento de identidad = 123456789
# Año de nacimiento = 2001
# País de nacimiento = Colombia
# Género = M
# Nombres =  María Camila
# Apellidos = Rojas Herrera
# Documento de identidad = 987654321
# Año de nacimiento = 2004
# País de nacimiento = Colombia
# Género = M

# %% [markdown]
# ![Ejercicio 1 sin grid.png](data:image/png;base64,...)

# %% [markdown]
# Ejercicio 2.2 - Página 66

# %%
from enum import Enum

class PlanetType(Enum):
  Gaseous = "Gaseoso"
  Terrestial = "Terrestre"
  Dwarf = "Enano"

class Planet:
  def __init__(self, PlanetType, name = None, number_of_satellites = 0, mass_kg = 0.0, volume_m3 = 0.0, diameter_km = 0, av_sun_distance_Mkm = 0, Observable = False):
    self.name = str(name)
    self.number_of_satellites = int(number_of_satellites)
    self.mass_kg = float(mass_kg)
    self.volume_m3 = float(volume_m3)
    self.diameter_km = int(diameter_km)
    self.av_sun_distance_Mkm = int(av_sun_distance_Mkm)
    self.PlanetType = PlanetType
    self.Observable = Observable

  def print_information(self):
    print(f"Nombre = {self.name}")
    print(f"Número de satélites = {self.number_of_satellites}")
    print(f"Masa = {self.mass_kg} kg")
    print(f"Volumen = {self.volume_m3: .4e} m3")
    print(f"Diámetro = {self.diameter_km} km")
    print(f"Distancia al Sol = {self.av_sun_distance_Mkm} Mkm")
    print(f"Tipo de planeta = {self.PlanetType.value}")
    print(f"Es observable = {self.Observable}")
    density = self.calculate_density()
    print(f"Es planeta exterior = {self.determine_exterior_planet()}")

  def calculate_density(self):
    density = (self.mass_kg / self.volume_m3)
    print(f"Densidad del planeta es = {density: .3e} kg/m3")
    return


  def determine_exterior_planet(self):
    limit = 149597870 * 3.4
    if self.av_sun_distance_Mkm > limit:
      return True
    else:
      return False

if __name__ == "__main__":
  planet_1 = Planet(PlanetType.Terrestial, "Tierra", 1, 5.9736E24, 1.08321E12, 12742, 150000000, True)
  planet_2 = Planet(PlanetType.Gaseous, "Júpiter", 1, 1.899E27, 1.4314E15, 139820, 750000000, True)
  planet_1.print_information()
  planet_2.print_information()
# Out:
# Nombre = Tierra
# Número de satélites = 1
# Masa = 5.9736e+24 kg
# Volumen =  1.0832e+12 m3
# Diámetro = 12742 km
# Distancia al Sol = 150000000 Mkm
# Tipo de planeta = Terrestre
# Es observable = True
# Densidad del planeta es =  5.515e+12 kg/m3
# Es planeta exterior = False
# Nombre = Júpiter
# Número de satélites = 1
# Masa = 1.899e+27 kg
# Volumen =  1.4314e+15 m3
# Diámetro = 139820 km
# Distancia al Sol = 750000000 Mkm
# Tipo de planeta = Gaseoso
# Es observable = True
# Densidad del planeta es =  1.327e+12 kg/m3
# Es planeta exterior = True

# %% [markdown]
# ![Ejercicio 2 sin grid.png](data:image/png;base64,...)

# %% [markdown]
# Ejercicio 2.3 - Página 73

# %%
from enum import Enum

class TipoCombustible(Enum):
  GASOLINA = "Gasolina"
  DIESEL = "Diesel"
  BIOETANOL = "Bioetanol"
  BIODIESEL = "Biodiesel"
  GAS_NATURAL = "Gas natural"

class TipoAutomovil(Enum):
  CIUDAD = "Ciudad"
  SUBCOPACTO = "Subcompacto"
  COMPACTO = "Compacto"
  FAMILIAR = "Familiar"
  EJECUTIVO = "Ejecutivo"
  SUV = "SUV"

class Color(Enum):
  ROJO = "Rojo"
  NARANJA = "Naranja"
  AZUL = "Azul"
  VERDE = "Verde"
  AMARILLO = "Amarillo"
  VIOLETA = "Violeta"
  BLANCO = "Blanco"
  NEGRO = "Negro"


class Automovil():
  def __init__(self, marca, modelo, motor, tipo_combustible, tipo_automovil, numero_puertas, cantidad_asientos, velocidad_maxima, color, velocidad_actual = 0):
    self.marca = marca
    self.modelo = modelo
    self.motor = motor
    self.tipo_combustible = tipo_combustible
    self.tipo_automovil = tipo_automovil
    self.numero_puertas = numero_puertas
    self.cantidad_asientos = cantidad_asientos
    self.velocidad_maxima = velocidad_maxima
    self.color = color
    self.velocidad_actual = velocidad_actual

  # Métodos get
  def get_marca(self):
    return self.marca

  def get_modelo(self):
    return self.modelo

  def get_motor(self):
    return self.motor

  def get_tipo_combustible(self):
    return self.tipo_combustible

  def get_tipo_automovil(self):
    return self.tipo_automovil

  def get_numero_puertas(self):
    return self.numero_puertas

  def get_cantidad_asientos(self):
    return self.cantidad

  def get_velocidad_maxima(self):
    return self.velocidad_maxima

  def get_color(self):
    return self.color

  def get_velocidad_actual(self):
    return self.velocidad_actual

  # Métodos set
  def set_marca(self, marca):
    self.marca = marca

  def set_modelo(self, modelo):
    self.modelo = modelo

  def set_motor(self, motor):
    self.motor = motor

  def set_tipo_combustible(self, tipo_combustible):
    self.tipo_combustible = tipo_combustible

  def set_tipo_automovil(self, tipo_automovil):
    self.tipo_automovil = tipo_automovil

  def set_numero_puertas(self, numero_puertas):
    self.numero_puertas = numero_puertas

  def set_cantidad_asientos(self, cantidad_asientos):
    self.cantidad_asientos = cantidad_asientos

  def set_velocidad_maxima(self, velocidad_maxima):
    self.velocidad_maxima = velocidad_maxima

  def set_color(self, color):
    self.color = color

  def set_velocidad_actual(self, velocidad_actual):
    self.velocidad_actual = velocidad_actual

  # Otros métodos
  def acelerar(self, incremento_velocidad):
    if self.velocidad_actual + incremento_velocidad < self.velocidad_maxima:
      self.velocidad_actual += incremento_velocidad
    else:
      print(f"No es posible acelerar más de la velocidad límite")

  def desacelear(self, decremento_velocidad):
    if self.velocidad_actual - decremento_velocidad > 0:
      self.velocidad_actual -= decremento_velocidad
    else:
      print(f"No es posible desacelerar a velocidades negativas")

  def frenar(self):
    self.velocidad_actual = 0
    print(f"El vehículo ha sido detenido")

  def calcular_tiempo_llegada(self, distancia):
    if self.velocidad_actual > 0:
      tiempo_llegada = distancia / self.velocidad_actual
      return tiempo_llegada
    else:
      print("El vehículo no está en movimiento")

  def imprimir_valores(self):
    print(f'''\n**Información sobre el automóvil**\n
    Marca: {self.marca}
    Modelo: {self.modelo}
    Motor: {self.motor} Litros
    Tipo de combustible: {self.tipo_combustible.value}
    Tipo de automóvil: {self.tipo_automovil.value}
    Número de puertas: {self.numero_puertas}
    Cantidad de asientos: {self.cantidad_asientos}
    Velocidad máxima: {self.velocidad_maxima} km/h
    Color: {self.color.value}\n''')


if __name__ == "__main__":
  automovil_1 = Automovil("Ford", 2018, 3, TipoCombustible.DIESEL, TipoAutomovil.EJECUTIVO, 5, 6, 250, Color.NEGRO)
  automovil_1.imprimir_valores()

  automovil_1.set_velocidad_actual(100)
  print(f"Velocidad actual = {automovil_1.get_velocidad_actual()} km/h\n")

  automovil_1.acelerar(20)
  print(f"Velocidad actual = {automovil_1.get_velocidad_actual()} km/h\n")

  automovil_1.desacelear(50)
  print(f"Velocidad actual = {automovil_1.get_velocidad_actual()} km/h\n")

  automovil_1.frenar()
  print(f"Velocidad actual = {automovil_1.get_velocidad_actual()} km/h\n")

  #Caso límite velocidad mínima
  automovil_1.desacelear(200)
# Out:
# **Información sobre el automóvil**
#
#     Marca: Ford
#     Modelo: 2018
#     Motor: 3 Litros
#     Tipo de combustible: Diesel
#     Tipo de automóvil: Ejecutivo
#     Número de puertas: 5
#     Cantidad de asientos: 6
#     Velocidad máxima: 250 km/h
#     Color: Negro
#
# Velocidad actual = 100 km/h
#
# Velocidad actual = 120 km/h
#
# Velocidad actual = 70 km/h
#
# El vehículo ha sido detenido
# Velocidad actual = 0 km/h
#
# No es posible desacelerar a velocidades negativas

# %% [markdown]
# ![auto-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Ejercicio 2.4 - Página 86

# %%
import math

class Circulo():
  def __init__(self, radio):
    self.radio = radio

  def calcular_area(self):
    area = 3.14 * (self.radio ** 2)
    return area

  def calcular_perimetro(self):
    perimetro = 2 * 3.14 * self.radio
    return perimetro

class Rectangulo():
  def __init__(self, base, altura):
    self.base = base
    self.altura = altura

  def calcular_area(self):
    area = self.base * self.altura
    return area

  def calcular_perimetro(self):
    perimetro = 2 * (self.base + self.altura)
    return perimetro

class Cuadrado():
  def __init__(self, lado):
    self.lado = lado

  def calcular_area(self):
    area = self.lado * self.lado
    return area

  def calcular_perimetro(self):
    perimetro = 4 * self.lado
    return perimetro

class TrianguloRectangulo():
  def __init__(self, base, altura):
    self.base = base
    self.altura = altura

  def calcular_hipotenusa(self):
    hipotenusa = math.sqrt(self.base ** 2 + self.altura ** 2)
    return hipotenusa

  def calcular_area(self):
    area = (self.base * self.altura) / 2
    return area

  def calcular_perimetro(self):
    perimetro = self.base + self.altura + self.calcular_hipotenusa()
    return perimetro

  def determinar_tipo_triangulo(self):
    if (self.base == self.altura) and (self.base == self.calcular_hipotenusa()) and (self.altura == self.calcular_hipotenusa()):
      return ("Es un triángulo equilátero")
    elif (self.base != self.altura) and (self.base != self.calcular_hipotenusa()) and (self.altura != self.calcular_hipotenusa()):
      return ("Es un triángulo escaleno")
    else:
      return ("Es un triángulo isósceles")

class Rombo():
  def __init__(self, diagonal_mayor, diagonal_menor):
    self.diagonal_mayor = diagonal_mayor
    self.diagonal_menor = diagonal_menor
    self.lado = self.calcular_lado()

  def calcular_lado(self):
    # El lado del rombo es la hipotenusa de un triángulo rectángulo formado por la mitad de cada diagonal
    mitad_dmayor = self.diagonal_mayor / 2
    mitad_dmenor = self.diagonal_menor / 2
    lado = math.sqrt(mitad_dmayor ** 2 + mitad_dmenor ** 2)
    return lado

  def calcular_area(self):
    return (self.diagonal_mayor * self.diagonal_menor) / 2

  def calcular_perimetro(self):
    return 4 * self.lado



class PruebaFiguras():
    @staticmethod
    def main():
        circulo_1 = Circulo(2)
        rectangulo_1 = Rectangulo(1,2)
        cuadrado_1 = Cuadrado(3)
        triangulo_1 = TrianguloRectangulo(3,5)
        rombo_1 = Rombo(10,6)

        print(f''' ** Información Círculo **
    Área = {circulo_1.calcular_area()}
    Perímetro = {circulo_1.calcular_perimetro()}
    \n ** Información Rectángulo **
    Área = {rectangulo_1.calcular_area()}
    Perímetro = {rectangulo_1.calcular_perimetro()}
    \n ** Información Cuadrado **
    Área = {cuadrado_1.calcular_area()}
    Perímetro = {cuadrado_1.calcular_perimetro()}
    \n ** Información Triángulo **
    Área = {triangulo_1.calcular_area()}
    Perímetro = {triangulo_1.calcular_perimetro()}
    Tipo de triángulo: {triangulo_1.determinar_tipo_triangulo()}
    \n ** Información Rombo **
    Área = {rombo_1.calcular_area()}
    Perímetro = {rombo_1.calcular_perimetro()}''')


if __name__ == "__main__":
    PruebaFiguras.main()
# Out:
#  ** Información Círculo **
#     Área = 12.56
#     Perímetro = 12.56
#
#  ** Información Rectángulo **
#     Área = 2
#     Perímetro = 6
#
#  ** Información Cuadrado **
#     Área = 9
#     Perímetro = 12
#
#  ** Información Triángulo **
#     Área = 7.5
#     Perímetro = 13.8309518948453
#     Tipo de triángulo: Es un triángulo escaleno
#
#  ** Información Rombo **
#     Área = 30.0
#     Perímetro = 23.323807579381203

# %% [markdown]
# ![figuras.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Ejercicio 2.5 - Página 95

# %%
from enum import Enum

class AccountType(Enum):
  AHORROS = "Ahorros"
  CORRIENTE = "Corriente"

class Bank_Account:

  def __init__(self, names_holder, lastnames_holder, number_account, AccountType):
    self.names_holder = names_holder
    self.lastname_holder = lastnames_holder
    self.number_account = number_account
    self.AccountType = AccountType
    self.balance = 0

  def print_information(self):
    print(f"Nombres del titular = {self.names_holder}")
    print(f"Apellidos del titular = {self.lastname_holder}")
    print(f"Número de cuenta = {self.number_account}")
    print(f"Tipo de cuenta = {self.AccountType.value}")
    print(f"Saldo = {self.balance}")

  def check_balance(self):
    print(f"El saldo actual es = {self.balance}")

  def deposit(self, amount):
    if amount > 0:
      self.balance += amount
      print (f"Se ha consignado ${amount} en la cuenta. El nuevo saldo es ${self.balance}")
      return True
    else:
      print("El valor a consignar debe ser mayor a cero.")
      return False

  def withdraw(self, amount):
    if amount > 0 and amount <= self.balance:
      self.balance -= amount
      print(f"Se ha retirado ${amount} de la cuenta. El nuevo saldo es ${self.balance}")
      return True
    else:
      print("El valor a retirar debe ser menor que el saldo actual.")
      return False

if __name__ == "__main__":
  account = Bank_Account("Pedro", "Pérez", 123456789, AccountType.AHORROS)
  account.print_information()
  account.deposit(200000)
  account.deposit(300000)
  account.withdraw(400000)
# Out:
# Nombres del titular = Pedro
# Apellidos del titular = Pérez
# Número de cuenta = 123456789
# Tipo de cuenta = Ahorros
# Saldo = 0
# Se ha consignado $200000 en la cuenta. El nuevo saldo es $200000
# Se ha consignado $300000 en la cuenta. El nuevo saldo es $500000
# Se ha retirado $400000 de la cuenta. El nuevo saldo es $100000

# %% [markdown]
# ![Ejercicio 5 sin grid.png](data:image/png;base64,...)
